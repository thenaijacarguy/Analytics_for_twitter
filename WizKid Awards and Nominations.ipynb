# %% [markdown]
# # Importing a table from WikiPedia and converting to a DataFrame

# %% [markdown]
# Firstly, Import Pandas

# %%
import pandas as pd

# %% [markdown]
# Then import Requests

# %%
import requests

# %% [markdown]
# Then install Beautiful Soup

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Then import Beautiful Soup

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# # Next step, check to see if we have permission to import the table from WikiPedia

# %% [markdown]
# A 200 status code tells us that it's alright to access information from a certain website

# %%
wikiurl='https://en.wikipedia.org/wiki/List_of_awards_and_nominations_received_by_Burna_Boy'
table_class="wikitable sortable jquery-tablesorter"
response=requests.get(wikiurl)
print(response.status_code)
# Out:
# 200

# %% [markdown]
# Now, we proceed to import the table using Beautiful Soup

# %%
soup=BeautifulSoup(response.text, 'html.parser')
wiz = soup.find('table', {'class': 'wikitable'})

# %% [markdown]
# Assigning the table a name 'wizkid'

# %%
wizkid = pd.read_html(str(wiz))

# %%
wizkid
# Out:
# [                                Award  Year  \
#  0                       3Music Awards  2022
#  1    African Entertainment Awards USA  2021
#  2    African Entertainment Awards USA  2021
#  3    African Entertainment Awards USA  2021
#  4    African Entertainment Awards USA  2021
#  ..                                ...   ...
#  258       4Syte TV Music Video Awards  2015
#  259       4Syte TV Music Video Awards  2019
#  260       4Syte TV Music Video Awards  2019
#  261       4Syte TV Music Video Awards  2019
#  262       4Syte TV Music Video Awards  2019
#
#                                     Category  \
#  0                  African Song of the Year
#  1                          Best Male Artist
#  2                        Artist of the Year
#  3    Best Male Artist – Central/West Africa
#  4                         Album Of The Year
#  ..                                      ...
#  258                  Best African Act Video
#  259                         Best Male Video
# ...

# %% [markdown]
# # Converting the table to a Pandas DataFrame

# %%
wizkid = pd.DataFrame(wizkid[0])

# %% [markdown]
# Now, let's see what the table looks like after being converted to a dataframe

# %%
wizkid
# Out:
#     Year                          Event  \
# 0   2013       South South Music Awards
# 1   2013   Nigeria Entertainment Awards
# 2   2013                    The Headies
# 3   2013                    The Headies
# 4   2014        MTV Africa Music Awards
# 5   2014                    The Headies
# 6   2014                    The Headies
# 7   2014                    The Headies
# 8   2014                    The Headies
# 9   2014   Nigeria Entertainment Awards
# 10  2015   Nigeria Entertainment Awards
# 11  2019  Soundcity MVP Awards Festival
# 12  2019  Soundcity MVP Awards Festival
# 13  2019  Soundcity MVP Awards Festival
# 14  2019  Soundcity MVP Awards Festival
# 15  2019                     BET Awards
# 16  2019                    The Headies
# 17  2019                    The Headies
# 18  2019                    The Headies
# 19  2019                    The Headies
# 20  2019                    The Headies
# 21  2019                    The Headies
# ...

# %% [markdown]
# # Dropping unwanted columns

# %% [markdown]
# The last column is not necessary and needs to go

# %%
wizkid=wizkid.drop('Ref', axis=1)

# %%
wizkid
# Out:
#     Year                          Event  \
# 0   2013       South South Music Awards
# 1   2013   Nigeria Entertainment Awards
# 2   2013                    The Headies
# 3   2013                    The Headies
# 4   2014        MTV Africa Music Awards
# 5   2014                    The Headies
# 6   2014                    The Headies
# 7   2014                    The Headies
# 8   2014                    The Headies
# 9   2014   Nigeria Entertainment Awards
# 10  2015   Nigeria Entertainment Awards
# 11  2019  Soundcity MVP Awards Festival
# 12  2019  Soundcity MVP Awards Festival
# 13  2019  Soundcity MVP Awards Festival
# 14  2019  Soundcity MVP Awards Festival
# 15  2019                     BET Awards
# 16  2019                    The Headies
# 17  2019                    The Headies
# 18  2019                    The Headies
# 19  2019                    The Headies
# 20  2019                    The Headies
# 21  2019                    The Headies
# ...

# %% [markdown]
# # Making a column the index

# %% [markdown]
# Next, we make the Award column the index so it can be plottable as a graph

# %%
wizkid = wizkid.set_index('Event')

# %%
wizkid
# Out:
#                                Year                                  Prize  \
# Event
# South South Music Awards       2013               South South Music Awards
# Nigeria Entertainment Awards   2013           Nigeria Entertainment Awards
# The Headies                    2013                             Next Rated
# The Headies                    2013                        Best R&B Single
# MTV Africa Music Awards        2014                           Best New Act
# The Headies                    2014                        Best R&B Single
# The Headies                    2014                     Best R&B/Pop Album
# The Headies                    2014   Hip Hop World Revelation of the Year
# The Headies                    2014                      Album of the Year
# Nigeria Entertainment Awards   2014                 Best Album of the Year
# Nigeria Entertainment Awards   2015            Best Pop Artist of the Year
# ...

# %% [markdown]
# # Exporting the DstaFrame as a CSV to use in Power BI

# %%
wizkid.to_csv('B.csv')

# %%
wizkid.to_excel('Burna.xlsx')
